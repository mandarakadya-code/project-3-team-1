# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creating a file
Co2=pd.read_csv('annual-co-emissions-by-region.csv')
Co2
# Out:
#             Entity Code  Year  annual_co2_emissions
# 0      Afghanistan  AFG  1949               14656.0
# 1      Afghanistan  AFG  1950               84272.0
# 2      Afghanistan  AFG  1951               91600.0
# 3      Afghanistan  AFG  1952               91600.0
# 4      Afghanistan  AFG  1953              106256.0
# ...            ...  ...   ...                   ...
# 30303     Zimbabwe  ZWE  2018            10714598.0
# 30304     Zimbabwe  ZWE  2019             9775428.0
# 30305     Zimbabwe  ZWE  2020             7849639.0
# 30306     Zimbabwe  ZWE  2021             8396158.0
# 30307     Zimbabwe  ZWE  2022             8855981.0
#
# [30308 rows x 4 columns]

# %%
Co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30308 entries, 0 to 30307
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entity                30308 non-null  object
#  1   Code                  24157 non-null  object
#  2   Year                  30308 non-null  int64
#  3   annual_co2_emissions  30308 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 947.3+ KB

# %%
Co2.drop('Code',axis=1,inplace=True)

# %%
Co2.rename(columns={'annual_co2_emissions':'A_Co2_emissions'},inplace=True)

# %%
Co2.head()
# Out:
#         Entity  Year  A_Co2_emissions
# 0  Afghanistan  1949          14656.0
# 1  Afghanistan  1950          84272.0
# 2  Afghanistan  1951          91600.0
# 3  Afghanistan  1952          91600.0
# 4  Afghanistan  1953         106256.0

# %%
Co2.Year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 1750, 1751, 1752,
#        1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763,
#        1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774,
#        1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785,
#        1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796,
#        1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807,
#        1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818,
# ...

# %%
Co2.Entity.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Africa (GCP)', 'Albania', 'Algeria',
#        'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Asia (GCP)', 'Asia (excl. China and India)', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Central African Republic', 'Central America (GCP)', 'Chad',
#        'Chile', 'China', 'Christmas Island', 'Colombia', 'Comoros',
#        'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia',
#        'Cuba', 'Curacao', 'Cyprus', 'Czechia',
# ...

# %%
# Change Entity to Country
Co2.rename(columns={'Entity':'Country'},inplace=True)

# %%
Co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30308 entries, 0 to 30307
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          30308 non-null  object
#  1   Year             30308 non-null  int64
#  2   A_Co2_emissions  30308 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 710.5+ KB

# %%
# Creating a condition to separate each year
condition=Co2['A_Co2_emissions']>=0
df=Co2[condition]

# %%
p1=df['Year']<=1959

# %%
Period_1=df[p1]

# %%
Period_1.head()
# Out:
#        Country  Year  A_Co2_emissions
# 0  Afghanistan  1949          14656.0
# 1  Afghanistan  1950          84272.0
# 2  Afghanistan  1951          91600.0
# 3  Afghanistan  1952          91600.0
# 4  Afghanistan  1953         106256.0

# %%
#Creating Period of 10 years
P1A=df['Year']<=1970
P1B=df['Year']>=1960

# %%
Period_2A=df[P1A&P1B]
Period_2A.head()
# Out:
#         Country  Year  A_Co2_emissions
# 11  Afghanistan  1960         413885.0
# 12  Afghanistan  1961         490798.0
# 13  Afghanistan  1962         688594.0
# 14  Afghanistan  1963         706736.0
# 15  Afghanistan  1964         838551.0

# %%
# Combine Year and Co2 Emissions
Period_2A.groupby('Year')['A_Co2_emissions'].sum().sort_values(ascending=False)
# Out:
# Year
# 1970    1.020537e+11
# 1969    9.449976e+10
# 1968    8.865822e+10
# 1967    8.407807e+10
# 1966    8.154702e+10
# 1965    7.789257e+10
# 1964    7.462881e+10
# 1963    7.080919e+10
# 1962    6.712419e+10
# 1961    6.465017e+10
# 1960    6.421359e+10
# Name: A_Co2_emissions, dtype: float64

# %%
Period_2A.Year.unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970],
#       dtype=int64)

# %%
Period_2A.groupby('Year')['A_Co2_emissions'].sum().sort_values(ascending=False)
# Out:
# Year
# 1970    1.020537e+11
# 1969    9.449976e+10
# 1968    8.865822e+10
# 1967    8.407807e+10
# 1966    8.154702e+10
# 1965    7.789257e+10
# 1964    7.462881e+10
# 1963    7.080919e+10
# 1962    6.712419e+10
# 1961    6.465017e+10
# 1960    6.421359e+10
# Name: A_Co2_emissions, dtype: float64

# %%
# Creating a bar graph and pie chart from 1960-1970( Just trying to see wnat is the data of 10 years compare to 20 years)
temp=Period_2A[['Year','A_Co2_emissions']].groupby('Year',as_index=False).mean()
temp= temp.sort_values(['A_Co2_emissions'],ascending=False)

fig, (ax1,ax2)= plt.subplots(1,2)
fig.suptitle('1960-1970 Co2 Emisssions', fontweight='bold',fontsize=25)
temp.head(11).plot.bar(x='Year',color='blue',figsize=(18,15),fontsize=20,ax=ax1)
ax1.set_ylabel('A_Co2_emissions',fontweight='bold',fontsize=20)
ax1.set_xlabel('Year',fontweight='bold',fontsize=15)
temp.head(11).plot(kind='pie',x='Year',y='A_Co2_emissions',figsize=(30,20),startangle=90,shadow= {'ox': -0.09, 'edgecolor': 'none', 'shade': 0.11},labels=temp['Year'],legend=False,fontsize=20,autopct="%1.1f%%",ax=ax2)
ax2.set_ylabel('')
ax2.set_xlabel('')
fig.subplots_adjust(hspace=0.0)

# %%
# Create Period of 20 years(1960-1980)
P2_Y1=df['Year']<=1980
P2_Y2=df['Year']>1959

# %%
Period_2=df[P2_Y1&P2_Y2]
Period_2.head()
# Out:
#         Country  Year  A_Co2_emissions
# 11  Afghanistan  1960         413885.0
# 12  Afghanistan  1961         490798.0
# 13  Afghanistan  1962         688594.0
# 14  Afghanistan  1963         706736.0
# 15  Afghanistan  1964         838551.0

# %%
Period_2.head()
# Out:
#         Country  Year  A_Co2_emissions
# 11  Afghanistan  1960         413885.0
# 12  Afghanistan  1961         490798.0
# 13  Afghanistan  1962         688594.0
# 14  Afghanistan  1963         706736.0
# 15  Afghanistan  1964         838551.0

# %%
Period_2.groupby('Country')['A_Co2_emissions'].sum().sort_values(ascending=False)[:65]
# Out:
# Country
# World                    3.041065e+11
# High-income countries    1.961827e+11
# OECD (GCP)               1.917237e+11
# Europe                   1.258363e+11
# Europe (GCP)             1.258363e+11
#                              ...
# Bulgaria                 1.222373e+09
# Saudi Arabia             1.221038e+09
# Denmark                  1.092742e+09
# Austria                  9.915848e+08
# Slovakia                 9.903294e+08
# Name: A_Co2_emissions, Length: 65, dtype: float64

# %%
# Creating a bar chart 10 countries that has highest Co2 Emissions
sns.set_style('darkgrid')
Period_2.groupby('Country')['A_Co2_emissions'].sum().sort_values(ascending=False)[1:10].plot(kind='bar')
plt.title('Top 10 Countries in emitting Co2 from 1960 to 1980',fontweight='bold')
plt.ylabel('Co2 Emissions')
# Out:
# Text(0, 0.5, 'Co2 Emissions')

# %%
Period_2.groupby('Year')['A_Co2_emissions'].sum().sort_values(ascending=False)
# Out:
# Year
# 1979    1.346584e+11
# 1980    1.340284e+11
# 1978    1.308957e+11
# 1977    1.269824e+11
# 1976    1.237238e+11
# 1975    1.171197e+11
# 1973    1.168281e+11
# 1974    1.166204e+11
# 1972    1.109939e+11
# 1971    1.062089e+11
# 1970    1.020537e+11
# 1969    9.449976e+10
# 1968    8.865822e+10
# 1967    8.407807e+10
# 1966    8.154702e+10
# 1965    7.789257e+10
# 1964    7.462881e+10
# 1963    7.080919e+10
# 1962    6.712419e+10
# 1961    6.465017e+10
# 1960    6.421359e+10
# Name: A_Co2_emissions, dtype: float64

# %% [markdown]
# # Creating a bar graph and pie chart from 1960-1980
# temp=Period_2[['Year','A_Co2_emissions']].groupby('Year',as_index=False).mean()
# temp= temp.sort_values(['A_Co2_emissions'],ascending=False)
#
# fig, (ax1,ax2)= plt.subplots(1,2)
# fig.suptitle('1960-1980 Co2 Emisssions', fontweight='bold',fontsize=30)
# temp.head(21).plot.bar(x='Year',color='blue',figsize=(25,20),fontsize=25,ax=ax1)
# ax1.set_ylabel('A_Co2_emissions',fontweight='bold',fontsize=20)
# ax1.set_xlabel('Year',fontweight='bold',fontsize=15)
# temp.head(21).plot(kind='pie',x='Year',y='A_Co2_emissions',figsize=(30,20),startangle=90,shadow= True,labels=temp['Year'],legend=False,fontsize=20,autopct="%1.1f%%",ax=ax2)
# ax2.set_ylabel('')
# ax2.set_xlabel('')
# fig.subplots_adjust(hspace=0.0)

# %%
# Change Year data types to object
Period_2['Year']=Period_2['Year'].astype('object')
Period_2.dtypes
# Out:
# C:\Users\laarn\AppData\Local\Temp\ipykernel_8528\4161569736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Period_2['Year']=Period_2['Year'].astype('object')
# Country             object
# Year                object
# A_Co2_emissions    float64
# dtype: object

# %%
Period_2.Year.unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980],
#       dtype=object)

# %%
Period_2.groupby('Year')['A_Co2_emissions'].sum().sort_values(ascending=False)
# Out:
# Year
# 1979    1.346584e+11
# 1980    1.340284e+11
# 1978    1.308957e+11
# 1977    1.269824e+11
# 1976    1.237238e+11
# 1975    1.171197e+11
# 1973    1.168281e+11
# 1974    1.166204e+11
# 1972    1.109939e+11
# 1971    1.062089e+11
# 1970    1.020537e+11
# 1969    9.449976e+10
# 1968    8.865822e+10
# 1967    8.407807e+10
# 1966    8.154702e+10
# 1965    7.789257e+10
# 1964    7.462881e+10
# 1963    7.080919e+10
# 1962    6.712419e+10
# 1961    6.465017e+10
# 1960    6.421359e+10
# Name: A_Co2_emissions, dtype: float64

# %%
Year_Total=Period_2.groupby(["Year"]).agg(
    {"A_Co2_emissions":["sum","max","mean",lambda x:x.max()-x.min()]})
Year_Total
# Out:
#      A_Co2_emissions
#                  sum           max          mean    <lambda_0>
# Year
# 1960    6.421359e+10  9.386421e+09  2.892504e+08  9.386421e+09
# 1961    6.465017e+10  9.414383e+09  2.899111e+08  9.414383e+09
# 1962    6.712419e+10  9.746556e+09  2.983297e+08  9.746556e+09
# 1963    7.080919e+10  1.026605e+10  3.133150e+08  1.026605e+10
# 1964    7.462881e+10  1.082362e+10  3.258900e+08  1.082362e+10
# 1965    7.789257e+10  1.130969e+10  3.401422e+08  1.130969e+10
# 1966    8.154702e+10  1.186171e+10  3.561005e+08  1.186171e+10
# 1967    8.407807e+10  1.223633e+10  3.671531e+08  1.223633e+10
# 1968    8.865822e+10  1.290434e+10  3.854705e+08  1.290434e+10
# 1969    9.449976e+10  1.376084e+10  4.108685e+08  1.376084e+10
# 1970    1.020537e+11  1.489816e+10  4.398868e+08  1.489816e+10
# 1971    1.062089e+11  1.550279e+10  4.558323e+08  1.550279e+10
# 1972    1.109939e+11  1.622344e+10  4.743329e+08  1.622344e+10
# ...

# %%
ax = sns.barplot(Period_2, x="Year", y="A_Co2_emissions", estimator="sum", errorbar=None)
ax.bar_label(ax.containers[0], fontsize=6);

# %%
sns.lineplot(data=Period_2, x="Year", y="A_Co2_emissions")
# Out:
# <Axes: xlabel='Year', ylabel='A_Co2_emissions'>

# %%
temp=Period_2[['Year','A_Co2_emissions']].groupby('Year',as_index=False).mean()
temp= temp.sort_values(['A_Co2_emissions'],ascending=False)

fig, (ax1,ax2)= plt.subplots(1,2)
fig.suptitle('1960-1980 Co2 Emisssions', fontweight='bold',fontsize=35)
temp.head(21).plot.bar(x='Year',color='blue',figsize=(30,25),fontsize=25,ax=ax1)
ax1.set_ylabel('A_Co2_emissions',fontweight='bold',fontsize=20)
ax1.set_xlabel('Year',fontweight='bold',fontsize=15)
temp.head(21).plot(kind='pie',x='Year',y='A_Co2_emissions',figsize=(30,20),startangle=90,shadow= True,labels=temp['Year'],legend=False,fontsize=20,autopct="%1.1f%%",ax=ax2)
ax2.set_ylabel('')
ax2.set_xlabel('')
fig.subplots_adjust(hspace=0.0)
